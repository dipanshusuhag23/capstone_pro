# %% [markdown]
# <a href="https://colab.research.google.com/github/dipanshusuhag23/capstone_pro/blob/main/Cap_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path = "/content/drive/MyDrive/austrain_states_data.csv"

# %%
df = pd.read_csv(path, encoding='iso-8859-1')

# %%
print(df.head())
# Out:
#            state population  population_percent foreign_citizens  \
# 0     Burgenland    301,000                   3           33,638
# 1      Carinthia    569,000                   6           72,911
# 2  Lower Austria  1,720,000                  19          205,053
# 3      Salzburg     561,000                   6          112,086
# 4         Styria  1,278,000                  14          172,073
#
#    foreign_citizens_percent  state_area_km2  city_count  capital_city  \
# 0                      11.2         3965.22          13    Eisenstadt
# 1                      12.8         9536.64          17    Klagenfurt
# 2                      11.9        19179.84          76  Sankt Pölten
# 3                      19.7         7154.50          11      Salzburg
# 4                      13.6        16399.51          35          Graz
#
#   capital_population gdp_per_capita_euro  city_area_km2        largest_lake  \
# 0             15,752              32,000          42.91       Neusiedlersee
# 1            104,333              40,300         120.10          Wörthersee
# 2             57,649              38,400         108.50  Stausee Ottenstein
# 3            159,003              53,300          65.68         Wolfgangsee
# 4            299,000              41,300         127.60           Grundlsee
#
#    lake_area km2  highest_mountain  mount_peak_meters
# 0         315.00  Geschriebenstein                884
# 1          19.39      Großglockner               3798
# 2           4.30     Klosterwappen               2076
# 3          13.00     Großvenediger               3674
# 4           5.00        Dachstein                2995

# %%
print(df.describe())
# Out:
#        population_percent  foreign_citizens_percent  state_area_km2  \
# count            9.000000                  9.000000        9.000000
# mean            11.000000                 17.433333     9320.372222
# std              7.088723                  7.123202     6357.593360
# min              3.000000                 11.200000      414.840000
# 25%              6.000000                 12.800000     3965.220000
# 50%              8.000000                 15.400000     9536.640000
# 75%             17.000000                 19.700000    12648.420000
# max             22.000000                 34.300000    19179.840000
#
#        city_count  city_area_km2  lake_area km2  mount_peak_meters
# count    9.000000       9.000000       9.000000           9.000000
# mean    22.333333     123.338889      52.523333        2671.555556
# std     23.081378     114.409897     100.689690        1233.917148
# min      1.000000      29.780000       0.320000         542.000000
# 25%     11.000000      65.680000       5.000000        2076.000000
# 50%     13.000000     104.900000      13.000000        2995.000000
# 75%     32.000000     120.100000      45.900000        3674.000000
# max     76.000000     414.600000     315.000000        3798.000000

# %%
import matplotlib.pyplot as plt

plt.bar(df['state'], df['population'])
plt.xticks(rotation=90)
plt.title('Population by State')
plt.xlabel('State')
plt.ylabel('Population')
plt.show()

# %%
plt.scatter(df['population'], df['state_area_km2'])
plt.title('population vs. Land Area')
plt.xlabel('Population')
plt.ylabel('Land Area (km2)')
plt.show()

# %%
plt.hist(df['foreign_citizens_percent'])
plt.title('Proportion of Foreign Citizens')
plt.xlabel('Foreign Citizens (%)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.barh(df['state'], df['city_count'])
plt.title('Number of Cities by State')
plt.xlabel('Number of Cities')
plt.ylabel('State')
plt.show()

# %%
plt.bar(df['state'], df['gdp_per_capita_euro'])
plt.xticks(rotation=90)
plt.title('GDP per capita of each state')
plt.xlabel('States')
plt.ylabel('GDP per Capita (€)')
plt.show()
